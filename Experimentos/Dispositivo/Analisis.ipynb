# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys

# %%
# Load data
ERIS_S8_1 = pd.read_csv('../Datos/ERIS_S8_1.csv')
ERIS_S8_2 = pd.read_csv('../Datos/ERIS_S8_2.csv')
ERIS_SCD30_1 = pd.read_csv('../Datos/ERIS_SCD30_1.csv')

# %%
ERIS_S8_1.resample('Q').mean()

# %%
ERIS_S8_1["CO2"].plot(grid=True, figsize=(15,5))
#ERIS_S8_2["CO2"].plot(grid=True, figsize=(15,5))
ERIS_SCD30_1["CO2"].plot(grid=True, figsize=(15,5))

# %%
ERIS_S8_1.resample('2T')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-e5779a6582d1> in <module>
# ----> 1 ERIS_S8_1.resample('2T')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in resample(self, rule, how, axis, fill_method, closed, label, convention, kind, loffset, limit, base, on, level)
#    8153                      axis=axis, kind=kind, loffset=loffset,
#    8154                      convention=convention,
# -> 8155                      base=base, key=on, level=level)
#    8156         return _maybe_process_deprecations(r,
#    8157                                            how=how,
#
# ~\Anaconda3\lib\site-packages\pandas\core\resample.py in resample(obj, kind, **kwds)
#    1248     """
#    1249     tg = TimeGrouper(**kwds)
# -> 1250     return tg._get_resampler(obj, kind=kind)
#    1251
#    1252
#
# ...

# %%
ERIS_S8_1.index = ERIS_S8_1["Unnamed: 0"]
# Out:
# 0       2021-03-02 17:36:45
# 1       2021-03-02 17:37:45
# 2       2021-03-02 17:38:45
# 3       2021-03-02 17:39:45
# 4       2021-03-02 17:40:45
# 5       2021-03-02 17:41:45
# 6       2021-03-02 17:42:45
# 7       2021-03-02 17:43:45
# 8       2021-03-02 17:44:45
# 9       2021-03-02 17:45:45
# 10      2021-03-02 17:46:45
# 11      2021-03-02 17:47:45
# 12      2021-03-02 17:48:45
# 13      2021-03-02 17:49:45
# 14      2021-03-02 17:50:45
# 15      2021-03-02 17:51:45
# 16      2021-03-02 17:52:45
# 17      2021-03-02 17:53:45
# 18      2021-03-02 17:54:45
# 19      2021-03-02 17:55:45
# 20      2021-03-02 17:56:45
# 21      2021-03-02 17:57:45
# 22      2021-03-02 17:58:45
# 23      2021-03-02 17:59:45
# 24      2021-03-02 18:00:45
# 25      2021-03-02 18:01:45
# 26      2021-03-02 18:02:45
# 27      2021-03-02 18:03:45
# 28      2021-03-02 18:04:45
# 29      2021-03-02 18:05:45
#                ...
# 1239    2021-03-03 14:46:07
# 1240    2021-03-03 14:47:07
# ...
