# %% [markdown]
# ### Lugar: Número del experimento
# Descripción

# %% [markdown]
# #### Dimensiones del aula
# Aula:
#
# | Alto | Ancho | Largo | Volumen |
# |----|-----|-----|-------|
# | Nan | Nan |Nan | Nan
#
# Ventanas/Puertas:
# - Puerta_1:
#
# | Alto | Ancho | Largo | Volumen |
# |----|-----|-----|-------|
# | Nan | Nan |Nan | Nan
#
# - Ventana_1
#
# | Alto | Ancho | Largo | Volumen |
# |----|-----|-----|-------|
# | Nan | Nan |Nan | Nan

# %%
import ach as ach

# %%
calidad = ach.ACH('../Datos/ERIS_S8_1.csv','2021-03-02 17:00:00','2021-03-02 20:14:00')
# Out:
# Calidad: Baja , ACH: 1.0847445595760241
