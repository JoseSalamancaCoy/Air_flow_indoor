# %% [markdown]
# ### Lugar: Número del experimento
# Descripción

# %% [markdown]
# #### Dimensiones del aula
# Aula:
#
# | Alto | Ancho | Largo | Volumen |
# |----|-----|-----|-------|
# | Nan | Nan |Nan | Nan
#
# Ventanas/Puertas:
# - Puerta_1:
#
# | Alto | Ancho | Largo | Volumen |
# |----|-----|-----|-------|
# | Nan | Nan |Nan | Nan
#
# - Ventana_1
#
# | Alto | Ancho | Largo | Volumen |
# |----|-----|-----|-------|
# | Nan | Nan |Nan | Nan

# %%
import ach as ach

# %%
import numpy as np

# %%
time  =['2021-03-01 15:30:00','2021-03-02 17:00:00','2021-03-02 17:00:00','2021-03-02 20:14:00','2021-03-02 20:14:00', '2021-03-02 20:30:00']
calidad = ach.ACH('../Datos/ERIS_S8_1.csv',time)
# Out:
# Calidad: Baja , ACH: 1.0846499718181906
