# %%
import ach as ach
import numpy as np
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-125371679c46> in <module>
# ----> 1 import ach as ach
#       2 import numpy as np
#       3 import pandas as pd
#
# ModuleNotFoundError: No module named 'ach'

# %%
data1 = ach.calibracion(['../Datos/aranet1.csv','../Datos/ERIS_S8_1.csv'],'2021-03-06 15:00:00','2021-03-06 19:20:00')
#data = ach.calibracion(['../Datos/aranet1.csv','../Datos/ERIS_SCD30_1.csv'],'2021-03-06 16:10:00','2021-03-06 17:20:00')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-792e792a4043> in <module>
# ----> 1 data1 = ach.calibracion(['../Datos/aranet1.csv','../Datos/ERIS_S8_1.csv'],'2021-03-06 15:00:00','2021-03-06 19:20:00')
#       2 #data = ach.calibracion(['../Datos/aranet1.csv','../Datos/ERIS_SCD30_1.csv'],'2021-03-06 16:10:00','2021-03-06 17:20:00')
#
# NameError: name 'ach' is not defined

# %%
data2 = ach.calibracion(['../Datos/aranet1.csv','../Datos/ERIS_S8_2.csv'],'2021-03-06 10:00:00','2021-03-06 19:20:00')
# Out:
# Coeficiente: 1.15933220405673    Interseccion: 6.534947406824131

# %%
data3 = ach.calibracion(['../Datos/aranet1.csv','../Datos/ERIS_SCD30_1.csv'],'2021-03-06 16:10:00','2021-03-06 19:20:00')
# Out:
# Coeficiente: 0.90618936443334    Interseccion: 113.72524591445904

# %% [markdown]
# #### Prueba 1
# Se dejo todo abierto

# %%
ach.ACH(data1,2,'2021-03-06 18:45:00','2021-03-06 19:20:00')
# Out:
# Calidad: Excelente , ACH: 5.966504011915764

# %%
ach.ACH(data2,2,'2021-03-06 18:45:00','2021-03-06 19:20:00')
# Out:
# Calidad: Excelente , ACH: 5.9664197129385315

# %%
ach.ACH(data3,2,'2021-03-06 18:45:00','2021-03-06 19:20:00')
# Out:
# Calidad: Excelente , ACH: 5.966840821416725

# %%
import matplotlib.pyplot as plt
x = [2,2,4,4,]
y = [2,4,2,4]
ach2 = [5.96,5.96,5.96,8.52]

# %%
plt.figure(figsize=(6,6))
plt.plot(x,y, ls = 'None', marker = '*')
plt.ylim(1,5)
plt.xlim(1,5)
for i in range(0,len(x)):
     plt.annotate(str(ach2[i]),(x[i]+0.2,y[i]+0.2))


plt.show()

# %%
data1.iloc[:,0].plot(label = 'aranet')
data1.iloc[:,2].plot(label = 's1')
data2.iloc[:,2].plot(label = 's2')
data3.iloc[:,2].plot(label = 's3')
plt.legend()
plt.xlim('2021-03-06 18:30:00','2021-03-06 19:45:00')
# Out:
# (26917590.0, 26917665.0)
